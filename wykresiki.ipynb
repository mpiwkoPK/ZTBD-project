# %%
import matplotlib.pyplot as plt

# %%
#insert sety - MySQL nieznormalizowane
times_10 = [3.7806315422058105, 2.8807544708251953, 3.126141309738159, 3.941927909851074, 5.652884244918823, 2.919110059738159, 2.624476671218872, 2.7989726066589355, 2.7420382499694824, 2.3315281867980957, 2.4848623275756836, 3.0530457496643066, 2.21451473236084, 2.2253966331481934, 2.3578758239746094]
times_100 = [2.8834006786346436, 2.649557113647461, 3.382612705230713, 4.204995632171631, 5.858585834503174, 4.325526714324951, 2.774860143661499, 2.8715951442718506, 3.431870222091675, 2.6349234580993652, 2.471552610397339, 2.9019157886505127, 2.304352045059204, 2.333082437515259, 2.470719575881958]
times_1000 = [4.429311513900757, 4.226368188858032, 5.380141019821167, 4.2798380851745605, 8.680473804473877, 7.362987518310547, 4.259538650512695, 4.972047805786133, 4.7127556800842285, 3.6472551822662354, 3.7888684272766113, 5.211650848388672, 3.9011361598968506, 3.612025499343872, 4.961894512176514]
times_5000 = [11.522732973098755, 11.113142013549805, 11.752353429794312, 11.120220184326172, 14.940059423446655, 17.6533842086792, 11.005474328994751, 12.31308650970459, 10.373551845550537, 9.868875980377197, 10.15450406074524, 11.233265161514282, 8.835930347442627, 12.036017894744873, 11.625298738479614]

x = range(15)
plt.figure(figsize=(10, 6))

plt.scatter(x, times_10, label='10 wierszy', color='red')
plt.scatter(x, times_100, label='100 wierszy', color='blue')
plt.scatter(x, times_1000, label='1000 wierszy', color='green')
plt.scatter(x, times_5000, label='5000 wierszy', color='orange')

plt.title('Czas wykonywania w zależności od liczby wczytywanych wierszy')
plt.xlabel('Próba')
plt.ylabel('Czas (s)')
plt.legend()
plt.grid(True)
plt.show()

# %%
#insert sety - PostgreSQL nieznormalizowane
times_10 = [3.7806315422058105, 2.8807544708251953, 3.126141309738159, 3.941927909851074, 5.652884244918823, 2.919110059738159, 2.624476671218872, 2.7989726066589355, 2.7420382499694824, 2.3315281867980957, 2.4848623275756836, 3.0530457496643066, 2.21451473236084, 2.2253966331481934, 2.3578758239746094]
times_100 = [2.8834006786346436, 2.649557113647461, 3.382612705230713, 4.204995632171631, 5.858585834503174, 4.325526714324951, 2.774860143661499, 2.8715951442718506, 3.431870222091675, 2.6349234580993652, 2.471552610397339, 2.9019157886505127, 2.304352045059204, 2.333082437515259, 2.470719575881958]
times_1000 = [4.429311513900757, 4.226368188858032, 5.380141019821167, 4.2798380851745605, 8.680473804473877, 7.362987518310547, 4.259538650512695, 4.972047805786133, 4.7127556800842285, 3.6472551822662354, 3.7888684272766113, 5.211650848388672, 3.9011361598968506, 3.612025499343872, 4.961894512176514]
times_5000 = [11.522732973098755, 11.113142013549805, 11.752353429794312, 11.120220184326172, 14.940059423446655, 17.6533842086792, 11.005474328994751, 12.31308650970459, 10.373551845550537, 9.868875980377197, 10.15450406074524, 11.233265161514282, 8.835930347442627, 12.036017894744873, 11.625298738479614]

x = range(15)
plt.figure(figsize=(10, 6))

plt.scatter(x, times_10, label='10 wierszy', color='red')
plt.scatter(x, times_100, label='100 wierszy', color='blue')
plt.scatter(x, times_1000, label='1000 wierszy', color='green')
plt.scatter(x, times_5000, label='5000 wierszy', color='orange')

plt.title('Czas wykonywania w zależności od liczby wczytywanych wierszy')
plt.xlabel('Próba')
plt.ylabel('Czas (s)')
plt.legend()
plt.grid(True)
plt.show()

# %%
#insert calosc z relacjami i zagniezdzone

times_mysql = [1494.7954726219177, 1501.1404900550842, 1494.8598272800446, 1581.7812333106995, 1504.8164801597595]
times_postgre = [1130.6845514774323, 1101.6721227169037, 1071.499491930008, 1070.275973558426, 1117.4283463954926]
times_mongo = [131.7580909729004, 80.6735007762909, 80.826815366745, 102.27739953994751, 129.8807029724121]

x = range(5)
plt.figure(figsize=(10, 6))

plt.scatter(x, times_mysql, label='MySQL', color='red')
plt.scatter(x, times_postgre, label='PostreSQL', color='blue')
plt.scatter(x, times_mongo, label='MongoDB', color='green')

plt.title('Czas wykonywania w zależności od SZBD')
plt.xlabel('Próba')
plt.ylabel('Czas (s)')
plt.legend()
plt.grid(True)
plt.show()

# %%
#insert calosc bez relacji i niezagniezdzone

times_mysql = [747.4933788776398, 774.5199463367462, 746.4460637569427, 820.0457298755646, 772.9238684177399]
times_postgre = [588.0855116844177, 510.67351818084717, 559.2733113765717, 506.6671988964081, 512.2292397022247]
times_mongo = [1716.1584312915802, 1049.8917400836945, 1790.9537799358368, 1055.2659831047058, 1042.365730524063]

x = range(5)
plt.figure(figsize=(10, 6))

plt.scatter(x, times_mysql, label='MySQL', color='red')
plt.scatter(x, times_postgre, label='PostreSQL', color='blue')
plt.scatter(x, times_mongo, label='MongoDB', color='green')

plt.title('Czas wykonywania w zależności od SZBD')
plt.xlabel('Próba')
plt.ylabel('Czas (s)')
plt.legend()
plt.grid(True)
plt.show()

# %%
#inesrt sety - MongoDB nieznormalizowane
times_10 = [0.2648341655731201, 0.18992161750793457, 0.19893646240234375, 0.19693541526794434, 0.18100929260253906, 0.18761396408081055, 0.18796753883361816, 0.1922767162322998, 0.1821761131286621, 0.17699503898620605, 0.18693208694458008, 0.19793462753295898, 0.18497467041015625, 0.18500161170959473, 0.19197678565979004]
times_100 = [0.28298187255859375, 0.29406094551086426, 0.31600236892700195, 0.27900004386901855, 0.3025360107421875, 0.2786285877227783, 0.2910041809082031, 0.3154001235961914, 0.310258150100708, 0.27397751808166504, 0.2850635051727295, 0.27904295921325684, 0.2882416248321533, 0.27924108505249023, 0.31792545318603516]
times_1000 = [1.033454418182373, 1.1080892086029053, 1.1605255603790283, 1.1528973579406738, 0.8424201011657715, 0.967158317565918, 0.8619668483734131, 1.146456241607666, 1.1750714778900146, 1.1312885284423828, 1.1056373119354248, 0.9412951469421387, 1.172936201095581, 1.0055432319641113, 0.9541471004486084]
times_5000 = [5.289244174957275, 3.7141339778900146, 4.19763708114624, 3.48101806640625, 3.5575289726257324, 3.6107707023620605, 3.9972290992736816, 4.360591888427734, 4.15645432472229, 4.3844523429870605, 4.369168758392334, 3.6341116428375244, 3.8672080039978027, 3.9489238262176514, 3.732415199279785]

x = range(15)
plt.figure(figsize=(10, 6))

plt.scatter(x, times_10, label='10 wierszy', color='red')
plt.scatter(x, times_100, label='100 wierszy', color='blue')
plt.scatter(x, times_1000, label='1000 wierszy', color='green')
plt.scatter(x, times_5000, label='5000 wierszy', color='orange')

plt.title('Czas wykonywania w zależności od liczby wczytywanych wierszy')
plt.xlabel('Próba')
plt.ylabel('Czas (s)')
plt.legend()
plt.grid(True)
plt.show()

# %%
#insert sety - MongoDB znormalizowane
times_10 = [0.24276971817016602, 0.1930084228515625, 0.22599339485168457, 0.19599699974060059, 0.19405484199523926, 0.21990633010864258, 0.19862890243530273, 0.22586345672607422, 0.21806621551513672, 0.20694828033447266, 0.20001697540283203, 0.23478293418884277, 0.29902029037475586, 0.24803376197814941, 0.20600295066833496]
times_100 = [0.6140737533569336, 0.6399452686309814, 0.6627030372619629, 0.6177024841308594, 0.6450932025909424, 0.6170012950897217, 0.5747699737548828, 0.6149616241455078, 0.5880107879638672, 0.5960233211517334, 0.6714069843292236, 0.6135985851287842, 0.6621298789978027, 0.6110074520111084, 0.623035192489624]

times_1000 = [5.675650358200073, 5.3869078159332275, 6.216498613357544, 5.367066860198975, 5.380467653274536, 5.342581748962402, 5.415962219238281, 5.40410852432251, 6.443148374557495, 6.239561319351196, 5.53322434425354, 5.964656591415405, 6.485752820968628, 6.134783744812012, 7.184667348861694]

times_5000 = [24.661661386489868, 24.318310737609863, 23.990804195404053, 23.773229598999023, 23.843417644500732, 23.472339391708374, 23.9055438041687, 23.987399578094482, 24.028745651245117, 26.72861075401306, 26.79616951942444, 25.82898449897766, 23.912938594818115, 23.723838806152344, 23.94914960861206]


x = range(15)
plt.figure(figsize=(10, 6))

plt.scatter(x, times_10, label='10 wierszy', color='red')
plt.scatter(x, times_100, label='100 wierszy', color='blue')
plt.scatter(x, times_1000, label='1000 wierszy', color='green')
plt.scatter(x, times_5000, label='5000 wierszy', color='orange')

plt.title('Czas wykonywania w zależności od liczby wczytywanych wierszy')
plt.xlabel('Próba')
plt.ylabel('Czas (s)')
plt.legend()
plt.grid(True)
plt.show()

# %%
#insert sety znormalizowane
#mysql
#10 - 0.156, 100 - 1.17, 1000 - 12.25, 5000 - 58.87
#mongodb
#10 - 0.22, 100 - 0.62, 1000 - 5.88, 5000 - 24.46
#postgre 
#10 - 0.514605, 100 - 3.3539364337, 1000 - 19.63902807, 5000 - 114.057

import matplotlib.pyplot as plt

# Dane z pomiarów czasu dla MySQL, MongoDB i PostgreSQL
# Format danych: {liczba_wierszy: czas_wstawiania}
mysql_data = {10: 0.156, 100: 1.17, 1000: 12.25, 5000: 58.87}
mongodb_data = {10: 0.22, 100: 0.62, 1000: 5.88, 5000: 24.46}
postgres_data = {10: 0.514605, 100: 3.3539364337, 1000: 19.63902807, 5000: 114.057}

# Tworzenie wykresu
plt.figure(figsize=(10, 6))

# Dodawanie danych dla MySQL
plt.plot(list(mysql_data.keys()), list(mysql_data.values()), marker='o', label='MySQL')

# Dodawanie danych dla MongoDB
plt.plot(list(mongodb_data.keys()), list(mongodb_data.values()), marker='o', label='MongoDB')

# Dodawanie danych dla PostgreSQL
plt.plot(list(postgres_data.keys()), list(postgres_data.values()), marker='o', label='PostgreSQL')

# Dodawanie tytułów i etykiet osi
plt.title('Czasy wstawiania danych dla różnych baz danych')
plt.xlabel('Liczba wierszy')
plt.ylabel('Czas (s)')
plt.xticks(list(mysql_data.keys()))  # Ustawienie etykiet na osi X

# Dodawanie legendy
plt.legend()

# Wyświetlenie wykresu
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# # SELECT

# %%
#Select z parzystymi num_parts dla setu (zamiast #funkcja do pobierania kolorów o parzystych ID - 10 rekordów)
#mysql 0.004
#mongo 0.001
#postgre 0.003

# %%
#funkcja do pobierania wszystkich kolorów - 100 rekordów
#mysql 0.004
#mongo 2.34
#postgre 0.003

# %%
# odczytanie setow z poszczególnych lat + sortowanie malejąco według liczby części 
#mysql 2.85
#mongo 0.237
#postgre 0.265

# %%
# Odczytanie części z poszczególnych/konkretnej kategorii (setu)
#mysql 0.059
#mongo 0.003
#postgre 0.125

# %%
# najpopularniejsze motywy + ilosc zestawow w tym temacie 
#mysql 0.051
#mongo 0.055
#postgre 0.089

# %%
import numpy as np

# Nazwy zapytań
queries = [
    "Select z parzystymi num_parts dla setu",
    "Pobieranie wszystkich kolorów",
    "Odczytanie setów z lat + sortowanie",
    "Odczytanie części z kategorii",
    "Najpopularniejsze motywy"
]

# Czasy wykonania w sekundach dla MySQL, MongoDB i PostgreSQL
mysql_times = [0.004, 0.004, 2.85, 0.059, 0.051]
mongo_times = [0.001, 2.34, 0.237, 0.003, 0.055]
postgre_times = [0.003, 0.003, 0.265, 0.125, 0.089]

# Indeksy zapytań
indices = np.arange(len(queries))

# Szerokość słupków
bar_width = 0.2

# Pozycje słupków
bar1 = indices - bar_width
bar2 = indices
bar3 = indices + bar_width

# Tworzenie wykresu słupkowego
plt.figure(figsize=(12, 6))
plt.bar(bar1, mysql_times, color='lightblue', width=bar_width, edgecolor='grey', label='MySQL')
plt.bar(bar2, mongo_times, color='lightgreen', width=bar_width, edgecolor='grey', label='MongoDB')
plt.bar(bar3, postgre_times, color='lightcoral', width=bar_width, edgecolor='grey', label='PostgreSQL')

# Dodanie etykiet do osi
plt.xlabel('Zapytania', fontweight='bold')
plt.ylabel('Czas wykonania (s)', fontweight='bold')
plt.title('Porównanie czasów wykonania zapytań dla różnych baz danych', fontweight='bold')
plt.xticks(indices, queries, rotation=45)

# Dodanie legendy
plt.legend()

# Wyświetlenie wykresu
plt.tight_layout()
plt.show()

# %% [markdown]
# # Update

# %%
#SKOMPLILOWANY UPDATE
#Dla jednego setu:
# Zmienić kolor wszystkich części na "green".
# Zaktualizować num_parts na num_parts + 50.
# Zaktualizować quantity pierwszego elementu na quantity * 2.
# Zmienić theme_name na "Updated Classic".
#mysql 0.036 xd CZEMU TO JEST TAKIE SZYBKIE W T F (plik mysql/hub.py)
#mongo 0.008964300155639648
#postgre 0.4471275806427002

# %%
# PROSTY UPDATE aktualizacja zestawów z poszczególnych lat
#mysql 0.013
#mongo 0.0260012149810791
#postgre 0.0019996166229248047

# %%
queries = [
    "Skompilowany update dla jednego setu",
    "Prosty update zestawów z poszczególnych lat"
]

# Czasy wykonania w sekundach dla MySQL, MongoDB i PostgreSQL
mysql_times = [0.036, 0.013]
mongo_times = [0.008964300155639648, 0.0260012149810791]
postgre_times = [0.4471275806427002, 0.0019996166229248047]

# Indeksy zapytań
indices = np.arange(len(queries))

# Szerokość słupków
bar_width = 0.2

# Pozycje słupków
bar1 = indices - bar_width
bar2 = indices
bar3 = indices + bar_width

# Tworzenie wykresu słupkowego
plt.figure(figsize=(10, 6))
plt.bar(bar1, mysql_times, color='lightblue', width=bar_width, edgecolor='grey', label='MySQL')
plt.bar(bar2, mongo_times, color='lightgreen', width=bar_width, edgecolor='grey', label='MongoDB')
plt.bar(bar3, postgre_times, color='lightcoral', width=bar_width, edgecolor='grey', label='PostgreSQL')

# Dodanie etykiet do osi
plt.xlabel('Zapytania', fontweight='bold')
plt.ylabel('Czas wykonania (s)', fontweight='bold')
plt.title('Porównanie czasów wykonania update\'ów dla różnych baz danych', fontweight='bold')
plt.xticks(indices, queries, rotation=0)

# Dodanie legendy
plt.legend()

# Wyświetlenie wykresu
plt.tight_layout()
plt.show()

# %% [markdown]
# # DELETE

# %%
#Delete
#mysql 10 - 0.005, 100 - 0.005, 1000 - 0.03
#mongodb 10 - 0.016, 100 - 0.1, 1000 - 0.95
#postgre 10 - 0.082, 100 - 0.084, 1000 - 0.087

# Dane z pomiarów czasu dla MySQL, MongoDB i PostgreSQL
# Format danych: {liczba_wierszy: czas_wstawiania}
mysql_data = {10: 0.005, 100: 0.005, 1000: 0.03}
mongodb_data = {10: 0.016, 100: 0.1, 1000: 0.95}
postgres_data = {10: 0.082, 100: 0.084, 1000: 0.087}

# Tworzenie wykresu
plt.figure(figsize=(10, 6))

# Dodawanie danych dla MySQL
plt.plot(list(mysql_data.keys()), list(mysql_data.values()), marker='o', label='MySQL')

# Dodawanie danych dla MongoDB
plt.plot(list(mongodb_data.keys()), list(mongodb_data.values()), marker='o', label='MongoDB')

# Dodawanie danych dla PostgreSQL
plt.plot(list(postgres_data.keys()), list(postgres_data.values()), marker='o', label='PostgreSQL')

# Dodawanie tytułów i etykiet osi
plt.title('Czasy usuwania danych dla różnych baz danych')
plt.xlabel('Liczba wierszy')
plt.ylabel('Czas (s)')
plt.xticks(list(mysql_data.keys()))  # Ustawienie etykiet na osi X

# Dodawanie legendy
plt.legend()

# Wyświetlenie wykresu
plt.grid(True)
plt.tight_layout()
plt.show()
